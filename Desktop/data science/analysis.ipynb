# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv('data.csv')

print(f"Total rows: {len(df)} | Total columns: {len(df.columns)}")
df.head()
# Out:
# Total rows: 30 | Total columns: 6
#          Date Product  Sales  Quantity Region Customer_Type
# 0  2024-01-01  Laptop   1200         2  North     Corporate
# 1  2024-01-02   Phone    800         5  South        Retail
# 2  2024-01-03  Tablet    600         3   East     Corporate
# 3  2024-01-04  Laptop   1200         1   West    Individual
# 4  2024-01-05   Phone    800         4  North        Retail

# %%
df.isnull().sum()
df.describe()
# Out:
#              Sales   Quantity
# count    30.000000  30.000000
# mean    835.000000   2.933333
# std     288.620381   1.552158
# min     450.000000   1.000000
# 25%     600.000000   2.000000
# 50%     800.000000   3.000000
# 75%    1200.000000   4.000000
# max    1200.000000   6.000000

# %%
total_sales = df['Sales'].sum()
avg_sales = df['Sales'].mean()

print(f"Total Sales: ${total_sales:,.2f}")
print(f"Average Sales: ${avg_sales:,.2f}")

top_products = df.groupby('Product')['Sales'].sum().sort_values(ascending=False)
sales_by_region = df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
sales_by_customer = df.groupby('Customer_Type')['Sales'].sum()
# Out:
# Total Sales: $25,050.00
# Average Sales: $835.00

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

top_products.plot(kind='bar', color='skyblue', edgecolor='black', ax=ax1)
ax1.set_title('Total Sales by Product', fontsize=14, fontweight='bold')
ax1.set_ylabel('Sales ($)')
ax1.tick_params(axis='x', rotation=45)

sales_by_region.plot(kind='bar', color='lightcoral', edgecolor='black', ax=ax2)
ax2.set_title('Total Sales by Region', fontsize=14, fontweight='bold')
ax2.set_ylabel('Sales ($)')
ax2.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
cd
# Out:
# C:\Users\JUST BUY PC
